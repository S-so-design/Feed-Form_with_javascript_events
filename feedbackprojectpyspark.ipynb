# %% [markdown]
# <a href="https://colab.research.google.com/github/S-so-design/-ai-id-verifier/blob/main/feedbackprojectpyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("FeedbackProject") \
    .master("local[*]") \
    .getOrCreate()

print("Spark started")
# Out:
# Spark started

# %%
data = [
    ("ROHITH", "good service", 5),
    ("SAI", "ok place", 3),
    ("NIKHIL", "bad experience", 2)
]

columns = ["name", "feedback", "rating"]

df = spark.createDataFrame(data, columns)
df.show()
# Out:
# +------+--------------+------+
# |  name|      feedback|rating|
# +------+--------------+------+
# |ROHITH|  good service|     5|
# |   SAI|      ok place|     3|
# |NIKHIL|bad experience|     2|
# +------+--------------+------+

# %%
from pyspark.sql.functions import avg

df.groupBy("rating").count().show()

df.select(avg("rating")).show()
# Out:
# +------+-----+
# |rating|count|
# +------+-----+
# |     5|    1|
# |     3|    1|
# |     2|    1|
# +------+-----+
#
# +------------------+
# |       avg(rating)|
# +------------------+
# |3.3333333333333335|
# +------------------+
